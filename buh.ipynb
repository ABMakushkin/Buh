# %%
pip install tabula-py
# Out:
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.0 MB 4.2 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/12.0 MB 4.2 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/12.0 MB 6.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.0/12.0 MB 6.0 MB/s eta 0:00:02
#    ------------------- -------------------- 5.8/12.0 MB 5.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.8/12.0 MB 5.6 MB/s eta 0:00:01
#    ------------------------ --------------- 7.3/12.0 MB 5.3 MB/s eta 0:00:01
#    -------------------------- ------------- 7.9/12.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.7/12.0 MB 4.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.9/12.0 MB 4.5 MB/s eta 0:00:01
# ...

# %%
import tabula

# Извлечь все таблицы из PDF (возвращает список DataFrame)
tables = tabula.read_pdf("document.pdf", pages="all", multiple_tables=True)

# Сохранить таблицы в CSV
for i, table in enumerate(tables, start=1):
    table.to_csv(f"table_{i}.csv", index=False)

# Или извлечь таблицу с конкретной страницы и области (если нужно уточнить)
tables = tabula.read_pdf(r"E:\_Diary\Buh_data\Выписка по счёту кредитной карты.pdf", pages=2, area=(50, 50, 500, 500))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import tabula
#       3 # Извлечь все таблицы из PDF (возвращает список DataFrame)
# ----> 4 tables = tabula.read_pdf("document.pdf", pages="all", multiple_tables=True)
#       6 # Сохранить таблицы в CSV
#       7 for i, table in enumerate(tables, start=1):
#
# File ~\anaconda3\Lib\site-packages\tabula\io.py:394, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, force_subprocess, options)
#     391 path, temporary = localize_file(input_path, user_agent, use_raw_url=use_raw_url)
#     393 if not os.path.exists(path):
# --> 394     raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), path)
# ...

# %%
import tabula

# %%
# Извлечь все таблицы из PDF (возвращает список DataFrame)
tables = tabula.read_pdf(r"E:\_Diary\Buh_data\Выписка по счёту кредитной карты.pdf", pages="all", multiple_tables=True)

# %%
pip install JPype1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
for i, table in enumerate(tables, start=1):
    table.to_csv(f"E:\\_Diary\\Buh_data\\table_{i}.csv", index=False, encoding='ANSI')

# %%
for i, table in enumerate(tables, start=1):
    print(type(table))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
tables[0]
# Out:
#     27.06.2025   18:57                                   Перевод на карту  \
# 0   27.06.2025  076494  Перевод от М. Андрей Борисович. Операция по карте
# 1          NaN     NaN                                           ****8519
# 2   27.06.2025   18:35                                       Супермаркеты
# 3   27.06.2025  330631        MOSCOW PYATEROCHKA (191). Операция по карте
# 4          NaN     NaN                                           ****8519
# 5   27.06.2025   13:37                                   Рестораны и кафе
# 6   27.06.2025  210697       MOSCOW FRESHKAFE. Операция по карте ****8519
# 7   27.06.2025   09:26                                   Рестораны и кафе
# 8   27.06.2025  211097       MOSCOW FRESHKAFE. Операция по карте ****8519
# 9   26.06.2025   12:31                                   Рестораны и кафе
# 10  26.06.2025  313600       MOSCOW FRESHKAFE. Операция по карте ****8519
# 11  26.06.2025   09:18                                   Рестораны и кафе
# ...

# %%
df = tables[0]

# %%
pd.DataFrame(df.columns)
# Out:
#                   0
# 0        27.06.2025
# 1             18:57
# 2  Перевод на карту
# 3        +92 364,00
# 4        251 759,36

# %%
import pandas as pd

# %%
pd.concat([pd.DataFrame(df.columns).T, df])
# Out:
#              0      1                 2           3           4  27.06.2025  \
# 0   27.06.2025  18:57  Перевод на карту  +92 364,00  251 759,36         NaN
# 0          NaN    NaN               NaN         NaN         NaN  27.06.2025
# 1          NaN    NaN               NaN         NaN         NaN         NaN
# 2          NaN    NaN               NaN         NaN         NaN  27.06.2025
# 3          NaN    NaN               NaN         NaN         NaN  27.06.2025
# 4          NaN    NaN               NaN         NaN         NaN         NaN
# 5          NaN    NaN               NaN         NaN         NaN  27.06.2025
# 6          NaN    NaN               NaN         NaN         NaN  27.06.2025
# 7          NaN    NaN               NaN         NaN         NaN  27.06.2025
# 8          NaN    NaN               NaN         NaN         NaN  27.06.2025
# 9          NaN    NaN               NaN         NaN         NaN  26.06.2025
# ...

# %%
qwe =pd.DataFrame(df.columns).T

# %%
qwe.columns = df.columns

# %%
qwe
# Out:
#    27.06.2025  18:57  Перевод на карту  +92 364,00  251 759,36
# 0  27.06.2025  18:57  Перевод на карту  +92 364,00  251 759,36

# %%
df = pd.concat([qwe, df])

# %%
df
# Out:
#     27.06.2025   18:57                                   Перевод на карту  \
# 0   27.06.2025   18:57                                   Перевод на карту
# 0   27.06.2025  076494  Перевод от М. Андрей Борисович. Операция по карте
# 1          NaN     NaN                                           ****8519
# 2   27.06.2025   18:35                                       Супермаркеты
# 3   27.06.2025  330631        MOSCOW PYATEROCHKA (191). Операция по карте
# 4          NaN     NaN                                           ****8519
# 5   27.06.2025   13:37                                   Рестораны и кафе
# 6   27.06.2025  210697       MOSCOW FRESHKAFE. Операция по карте ****8519
# 7   27.06.2025   09:26                                   Рестораны и кафе
# 8   27.06.2025  211097       MOSCOW FRESHKAFE. Операция по карте ****8519
# 9   26.06.2025   12:31                                   Рестораны и кафе
# 10  26.06.2025  313600       MOSCOW FRESHKAFE. Операция по карте ****8519
# ...
